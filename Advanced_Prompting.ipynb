# %%
from rich import print

# %%
# !ollama pull gemma2:2b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 7462734796d6... 100% ▕████████████████▏ 1.6 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling e18ad7af7efb... 100% ▕████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
from langchain_community.llms import Ollama
llm = Ollama(model="gemma2:2b")
llm.invoke("Why is the sky blue?")
# Out:
# "The sky appears blue due to a phenomenon called **Rayleigh scattering**. \n\nHere's how it works:\n\n1. **Sunlight:** Sunlight, which appears white to our eyes, is actually made up of all colors of the rainbow.  \n2. **Earth's atmosphere:** When sunlight enters Earth's atmosphere, it interacts with tiny particles like nitrogen and oxygen molecules.\n3. **Scattering:** These molecules are much smaller than the wavelength of visible light. As a result, they scatter light in different directions. \n4. **Blue wavelengths dominate:**  Blue light (shorter wavelengths) gets scattered more efficiently than other colors due to its higher energy. This means that we see blue more frequently in the sky.\n\n**Why not violet?** While violet light has even shorter wavelengths and scatters even more, our eyes are less sensitive to violet. We perceive a bluer sky than a pure violet one because of how our eyes react to different colors of light. \n\n\nIn summary:\n* **Earth's atmosphere:** Contains tiny particles that scatter sunlight.\n* **Rayleigh scattering:**  Shorter wavelengths of light (blue) are scattered more effectively, giving the sky its blue color. \n\n\nLet me know if you have any other questions! 😊\n"

# %% [markdown]
# # CoT - Chain of thought
# <span style="color:orange">
#
# Teach the model the method for solving a problem
#
# </span>

# %% [markdown]
# <div style="text-align: left; margin-top: 40px; margin-bottom: 40px;">
#
# <img src="https://www.promptingguide.ai/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Fcot.1933d9fe.png&w=1920&q=75" alt="Description of Image">
# </div>
# <span style="color:#eb323c">

# %%
# The difference is in the details of the answer
prompt_without_cot =   """Q: Roger has 5 tennis balls. He buys 2 more cans of
                        tennis balls. Each can has 3 tennis balls. How many
                        tennis balls does he have now?

                        A: The answer is 11.
                        
                        Q: The cafeteria had 23 apples. If they used 20 to
                        make lunch and bought 6 more, how many apples
                        do they have?
                        A:"""

prompt_with_cot = """Q: Roger has 5 tennis balls. He buys 2 more cans of
                        tennis balls. Each can has 3 tennis balls. How many
                        tennis balls does he have now?
                        
                        A: Roger started with 5 balls. 2 cans of 3 tennis balls
                        each is 6 tennis balls. 5 + 6 = 11. The answer is 11.
                        
                        Q: The cafeteria had 23 apples. If they used 20 to
                        make lunch and bought 6 more, how many apples
                        do they have?
                        A: """

# %%
print("[red]"+llm.invoke(prompt_without_cot)+"[/red]")
# Out:
# 23 + 20 = 43
# 43 - 6 = 37
#
#  37

# %%
print("[green]"+llm.invoke(prompt_with_cot)+"[green]")
# Out:
# Here's how to solve that problem step-by-step:
#
# * **Start with the initial amount:** The cafeteria had 23 apples.
# * **Subtract for lunch:**  They used 20 apples, so they have 23 - 20 = 3 apples left.
# * **Add the new apples:** They bought 6 more apples, bringing the total to 3 + 6 = 9 apples.
#
# **Answer:** The cafeteria has 9 apples now.

# %% [markdown]
# # Reverse Engineering
#
# Let's ask for a prompt that creates a blogpost similar to Tony Robbins's blogs
#
# https://www.tonyrobbins.com/blog/passive-income

# %%
example_blogpost = """
Ready for a truth most people won’t tell you? No matter the state of the economy, current politics or world events, you control the amount of money you make.

Current job not creating enough income? It’s time to get serious about passive income.

Tony says, “If you want to change your life you have to raise your standards.” This applies to relationships, career and finances alike. One way to raise your financial standards is with passive income ideas, which allow you to add to your income with minimal effort. You can learn how to make passive income and take charge of your financial future even in uncertain times. You can rise above and thrive – by creating a new you for the new world.

What is a passive income?
Passive income is money you earn without having to make a daily effort. Don’t be fooled by the word “passive” – most passive income ideas involve work, especially up front. Passive income isn’t about getting something for nothing. It’s about having a second, reliable source of income to help you create more financial freedom. While you’ll be doing more than kicking back and letting the cash roll in, once you’re set up, your passive income strategies will involve less work than your primary job.

What qualifies as passive income?
If you spend more than 500 hours of your time per year on that business or activity, that counts as material participation. If your participation makes up the majority of time anyone spent on the activity, or if you’ve participated for more than 100 hours and your participation is equal to other individuals’, that also counts as material participation. Both of these mean that the income from that business or activity is not passive income. What is a passive income is any activity that does not meet these thresholds but still provides you with regular earnings.

Types of passive income
According to the IRS, there are two types of passive income:

Trade or business activities in which you don’t materially participate during the year
Rental activities, even if you do materially participate in them
Within this definition, you can also break passive income down into three categories: investing, asset building and asset sharing. Investing is an example of an activity in which you don’t materially participate: passive income investments, like dividend stocks, real estate investment trusts or money market funds can make money without you lifting a finger. Building a real estate portfolio that you then rent out is also an example of investing.

Asset building and asset sharing are ways to have passive income in which you are materially involved. In asset building, you spend time building or gathering an income-generating asset, like music, photos or digital products, then create passive income by selling it. Asset sharing means using something you already own to make passive income. Airbnb is the perfect example of this type of passive income.

Getting started with passive income
For those wondering how to make passive income, it’s common to believe that you need a lot of money to get started. This is true for some passive income, such as real estate rentals or investing in or starting a business (although you can absolutely start a business with no investment). But there are plenty of passive income ideas that don’t require much money up front and are ideal for getting started.

If you’re wondering, “What about passive income for beginners?” it’s important to recognize that, beyond coming up with the perfect idea to make a passive income yourself, your psychology plays a massive role. Tony often says that business is 80% psychology and only 20% skill. Overcoming your limiting beliefs, eliminating fear of failure and working on your negotiating skills are just as essential as learning how to read financial statements. As with any business venture, when you start with your mental and emotional state, these passive income ideas are much more likely to succeed.

10 passive income ideas
The key to how to make passive income is to match your initial investment of time and energy to your risk tolerance level. (And of course, always do your research and consult an expert before making an investment or opening a new account). Here are some passive income ideas to get you started.

1. Real estate investment trusts (REITs)
REITs are one of the best passive income strategies and an excellent way to get started in real estate investing. They are low risk and don’t require a lot of money up front: you may be able to invest in an REIT for as little as $500. You buy shares in publicly traded real estate portfolios, and the REIT does the rest.

2. Real estate rentals
Rental activities are sometimes called semi-passive income because there is still work involved in being a landlord. However, once you’ve purchased a building and established regular tenants, you likely won’t be doing enough work to put you over the material participation threshold.

3. Money market accounts
Money market accounts are one of the best low-risk passive income investments for beginners. They’re similar to savings accounts, but their annual percentage yield (APY) is higher, and you’ll earn a better APY the more money you have in your account.

4. Index funds
Index funds invest in market indexes, which are broken down by company size, country, industries or styles, like fast-growing companies. Index funds aren’t the most exciting passive income investment, but they are easy to understand and reliable, making them another great option for beginners. Exchange-traded funds are a similar option with an even lower minimum investment required.

5. Dividend stocks
Dividend stocks require more research than money market accounts or index funds, but they can be one of the best ways to earn passive income. Dividend stocks come from publicly traded companies that share their profits on a regular basis. Many people own dividend stocks through retirement accounts, but you can also buy them through brokerage accounts.

6. Business investments
If you have a bit of money to invest, look into becoming an equity partner in an existing business that needs capital. You can also start a semi-passive business like a laundromat, car wash or vending machine installation. Once set up, these businesses don’t require much involvement from upper management.

7. Using your expertise
There are passive income ideas that don’t involve investing – like using your expertise to create and sell content. Make a guide or an instructional video explaining a complicated product or topic, or create a course and post it online. You’ll receive income every time someone buys your video or signs up for your course, with no further effort required.

8. Creative pursuits
If your expertise is creative, you’re in luck. Discover how to make passive income by creating and licensing music, selling stock photography or writing a book or ebook. Turn your artwork into digital files to sell online. Create and sell T-shirt designs. You may be surprised how you can monetize your talent.

9. Affiliate marketing
Affiliate marketing is a way to get paid for promoting products, similar to influencer marketing. For this passive income idea, you’ll need a website or blog. You can create one on your own or, with a little negotiation, purchase an existing blog for about $1,000 to $3,000. Then choose products to review and promote – every time you make a sale, you’ll get a commission.

10. Renting out your home or car
Did you know that Airbnb and Vrbo qualify as passive income? Renting out your spare room – or your entire house ­– can provide you with regular income for little effort. You can even rent out your car or your RV for temporary use. Just keep wear and tear in mind, and make sure you have the right insurance coverage.

Take a look around you – what skills or assets do you already have that you can leverage for income? What could you easily create? With the right mindset and a little creativity, you can come up with even more passive income ideas.

"""
print(llm.invoke(f"Reverse engineer a prompt that creates a blogpost similiar to this blogpost: {example_blogpost}"))
# Out:
# ##  Generate Your Own Passive Income: A Guide to Financial Freedom
#
# **Are you stuck in a rut? Feeling like your financial situation isn't where it could be? You are not alone.**  Many
# people face similar challenges, feeling trapped by the constraints of their current circumstances. But what if
# there was a way to **gain control of your financial future,** even during uncertain times?
#
# **This article will show you how to unlock the power of passive income – earning money without constantly working
# for it!** This guide unlocks the door to a life where financial freedom is within reach.
#
# **Ready to discover your path to passive income? Let's dive in!**
#
#
# **What exactly IS Passive Income?**
# Contrary to popular belief, "passive" doesn't mean doing absolutely nothing. It means **creating a system that
# generates consistent income with minimal effort.** Think of it as setting yourself up for long-term financial
# success, so your hard work translates into lasting benefits.
#
# **Why Should You Care About Passive Income?**
# Imagine earning money even when you're sleeping or taking a vacation – that's the power of passive income! This
# financial freedom can:
#
# * **Boost Your Savings:** Diversify your income to weather any economic storm.
# * **Secure Your Future:**  Build a financial cushion for unexpected expenses or retirement.
# * **Unlock Your Freedom:** Take control and pursue passions you might not have time for otherwise.
#
# **Types of Passive Income You Can Explore!**
#
# 1. **Investment-based Opportunities:** These are your classic passive income options, where you earn returns
# without actively managing them:
#     * **REITs (Real Estate Investment Trusts):** Low-risk investment in real estate portfolios with minimal capital
# needed.
#     * **Money Market Accounts:** Earn higher interest on savings than traditional accounts.
#     * **Index Funds & ETFs:** Diversified investments that track market indexes for consistent, long-term growth.
#     * **Dividend Stocks:** Invest in companies that distribute profits regularly – a steady income stream for your
# portfolio.
#
# 2. **Skills and Assets to Monetize:** Utilize your existing talents and resources to generate passive income:
#     * **Create & Sell Digital Content:** Books, guides, online courses – share your expertise with the world!
#     * **Creative Pursuits:** Music, photography, writing - turn your artistic talents into lucrative opportunities.
#     * **Affiliate Marketing:**  Promote products and earn commissions through your blog or website.
#     * **Renting Out Assets:**  Explore options like renting out a spare room, car, or even your RV for temporary
# use.
#
# **Your Journey to Passive Income Begins Here!**
#
# This is just a glimpse into the vast potential of passive income. The key is to find what works best for you –
# **explore these opportunities, discover your strengths, and build a system that aligns with your goals.**
#
#
# **Ready to start building a brighter financial future?  Take action today!**
#
#
#
# **Pro-Tip:** For deeper research and insights into specific passive income strategies, explore resources like [Name
# of Online Course/Platform] or visit websites dedicated to personal finance. You can also join communities of
# successful individuals who have mastered the art of earning passive income – they are a valuable source of
# knowledge and support on your journey.

# %% [markdown]
# # Take a step back prompting
#
# <div style="text-align: left; margin-top: 40px; margin-bottom: 40px;">
#
# <img src="https://miro.medium.com/v2/resize:fit:2000/format:webp/1*C-M88KonAuQhIGg5rlos-g.png" alt="Description of Image">
# </div>
# <span style="color:#eb323c">

# %% [markdown]
# <span style="color:orange">
#
# Protons: 19
#
# Neutrons: 21
#
# Electrons: 18
#
# </span>

# %%
original_question = """ 
    How many protons, neutrons, and electrons does potassium-40 have when it is part of K2SO4?
    Protons: 
    Neutrons:
    Electrons: 
"""
print("[red]"+llm.invoke(original_question)+"[red]")

step_back_question = """
    What are the principles behind the question?
    Question:
"""

stepback_answer = llm.invoke(step_back_question + original_question)
print(stepback_answer)

final_answer = llm.invoke(original_question + stepback_answer)
print("[green]"+final_answer+"[green]")
# Out:
# Here's how to figure out the number of protons, neutrons, and electrons in potassium-40 (K-40) within the compound
# K₂SO₄:
#
# **1. Understanding Potassium-40 (K-40)**
#
# * **Protons:**  Potassium has an atomic number of 19, meaning it has 19 protons. So, K-40 has 19 protons.
# * **Neutrons:** The mass of a potassium atom with 40 neutrons is approximately the same as the mass of a potassium
# atom in its natural state, which is also 19 protons, and 21 neutrons (since it's a naturally occurring isotope).
#
# **2. Understanding Potassium Sulfate (K₂SO₄)**
#
# * **Ionic Bonds:**  The chemical formula K₂SO₄ shows that potassium (K) combines with sulfate (SO₄).
# * **Electronegativity:** Potassium is highly electronegative and will attract electrons in the process of forming a
# bond, resulting in a positively charged cation (Potassium). Sulfur has a higher electronegativity than oxygen and
# forms the negative part of the bond, thus allowing the compound to have an overall neutral charge.
#
# **3. Calculating Electrons in K₂SO₄**
#     * Potassium-40 has 19 protons, and since it is an isotope of potassium, it will still have 19 neutrons, forming
# a cation. Since it's an ionic compound, the number of electrons will be equal to the number of protons, so this ion
# can also have 19 electrons.
#
# **Summary:**
#
# * **Protons: 19** (in K-40)
# * **Neutrons: 21**  (in K-40)
# * **Electrons: 19** (for the neutral potassium ion)
#
#
# Let me know if you have any more chemistry questions!
# Let's break down this chemistry question!
#
# **Understanding the Question:**
#
# The question is asking for the **subatomic makeup** of potassium-40 within the compound K₂SO₄.  Here's why this is
# important and how to approach it:
#
# * **Atomic Structure Basics:**
#     * **Protons:** Positively charged particles found in the nucleus of an atom (the "core" of the element).
#     * **Neutrons:** Neutrally charged particles also found in the nucleus. These contribute to the atom's mass but
# don't have a charge.
#     * **Electrons:** Negatively charged particles that orbit the nucleus. They determine an atom's reactivity and
# bonding behavior.
#
# * **Potassium-40 (K-⁴₀):** The question refers to a specific isotope of potassium with 40 protons. Isotopes are
# atoms of the same element (same number of protons) but different numbers of neutrons, leading to varying atomic
# masses.
#
# * **K₂SO₄ (Potassium Sulfate):** This is a compound made up of two potassium atoms (each with 19 protons), one
# sulfur atom with 16 protons, and four oxygen atoms each with 8 protons.
#
# **Finding the Answer:**
#
# To find the number of protons, neutrons, and electrons in K-⁴₀ within the K₂SO₄ compound, we need to do a bit of
# work:
#
# * **Potassium-40 (K-⁴₀):** This is a *stable isotope*
#     * Protons: 19 (always stays the same)
#     * Neutrons: 40 (different from K-39, which has 38 neutrons)
#     * Electrons: 19 (same as protons).
#
# * **K₂SO₄:**  This compound is made of two potassium atoms (each with 19 protons) and other particles. You can use
# this information to calculate the number of electrons in K₂SO₄.
#
#
# **Key Takeaways:**
#    * The question asks for the *state of matter* of the atom as it relates to the compound.
#    * It is important to remember that elements are defined by their protons, and isotopes are defined by their
# neutron numbers.
#    * Understanding atomic structure allows us to solve this problem.
# You're doing great! Here's a breakdown of how to find the answer, along with some clarification:
#
# **Understanding the Question:**
#
# The question is asking about the *subatomic makeup* of potassium-40 within the compound K₂SO₄. Let me explain why
# that matters.
#
# * **Isotopes and Their Impact:**  Potassium has two common isotopes (versions) with different numbers of neutrons,
# making them slightly heavier or lighter:
#     * **K-39:**  has 19 protons and 20 neutrons (atomic mass: 39)
#     * **K-40:** has 19 protons and 40 neutrons (atomic mass: 40)
#
# We need to know the exact arrangement of atoms within K₂SO₄.
#
#
# **Step-by-step Approach for Finding the Answer:**
#
# 1.  **Potassium-40 (K-⁴₀):** This is a *stable isotope*, meaning it doesn't decay and has a specific number of
# neutrons in its nucleus.
#     * **Protons:** 19 (always stays the same)
#     * **Neutrons:** 40 (this is why K-⁴₀ is heavier than K-39)
#     * **Electrons:** 19 (same as protons).
#
# 2.  **K₂SO₄ (Potassium Sulfate):** This compound has two potassium atoms in it, each with 19 protons:
#      * The compound's chemical formula means that there are two potassium ions (K⁺) in each unit of the compound.
#
#
# **Key Points:**
#
# * **Atomic Mass:**  An atom's atomic mass is a combination of its protons and neutrons.
# * **Stable Isotopes:**  Potassium-40 is stable, meaning it doesn't decay over time, and it has 40 neutrons in its
# nucleus.
#
#
# Let me know if you have any other chemistry questions!

# %%
original_question = """ 
    What happens to the pressure of an ideal gas when temperature increases 
    by a factor of 2, and volume increases by a factor of 8?
"""
print("[red]"+llm.invoke(original_question)+"[red]")

step_back_question = """
    What are the fundamental concepts or principles involved in this problem?
"""

stepback_answer = llm.invoke(step_back_question + original_question)
print(stepback_answer)

final_answer = llm.invoke("Use: " + stepback_answer + " and asnwer question: " + original_question + " answer:")

print("[green]"+final_answer+"[green]")
# Out:
# Here's how to break down the relationship between pressure, temperature, and volume for an ideal gas:
#
# **Understanding Ideal Gas Law**
#
# The ideal gas law is given by:
#
# * **PV = nRT**
#
# where:
#    * P = Pressure
#    * V = Volume
#    * n = Number of moles (constant)
#    * R = Ideal gas constant
#    * T = Temperature (in Kelvin)
#
# **Key Concepts:**
#
# * **Direct Proportionality:**  Temperature and pressure are directly proportional.  If you increase the
# temperature, pressure increases (and vice-versa).
# * **Boyle's Law:** Pressure and volume have an inverse relationship (for a constant temperature).
# * **Charles's Law:** Volume and temperature have an inverse relationship (for a constant pressure).
#
#
# **Applying the Information to Your Problem**
#
# 1. **Temperature Increase:** You increase the temperature by a factor of 2, meaning T = 2T.
# 2. **Volume Increase:**  The volume increases by a factor of 8, meaning V = 8V.
#
# **Solving for New Pressure (P)**
#
# We can use the ideal gas law to solve for the new pressure:
#
# 1. **Original equation:** PV = nRT
# 2. **Substitute your values**: P * V = nR T
# 3. **Use substitution:** (P * 8V) = nR *(2T)
# 4. **Simplify and rearrange to find P:**  P * 8V = 2nR T
#
# **Therefore, the pressure of the gas will also increase by a factor of 2 (or 8*1/2). This is because temperature
# increases directly affect the pressure.**
#
#
#
# Let me know if you have any other questions!
# Here's a breakdown of the concepts involved and how they apply to your problem:
#
# **Fundamental Concepts**
#
# * **Ideal Gas Law:** This law describes the relationship between pressure, volume, temperature, and amount of gas
# in a system. The ideal gas law is expressed as:
#    **PV = nRT**
#     Where:
#        * P = Pressure (usually measured in Pascals)
#        * V = Volume (usually measured in cubic meters or liters)
#        * n = Number of moles of gas
#        * R = Ideal Gas Constant (8.314 J/mol·K)  (Note: This constant is specific to the units used for pressure,
# volume, and temperature)
#        * T = Temperature (measured in Kelvin)
#
# * **Temperature & Kinetic Energy:**  The faster the particles of a gas move (higher temperature), the more energy
# they possess. This increased energy leads to greater movement and collisions with each other, resulting in higher
# pressure.
#
# * **Pressure:** Pressure is defined as force applied per unit area. In this case, the molecules of the gas exert
# pressure on the walls of their container.
#
#
# **How Temperature & Volume Influence Pressure (for Ideal Gases)**
#
# 1. **Relationship Between Pressure, Temperature and Volume:** The ideal gas law shows that these three factors are
# interconnected.  For an ideal gas under constant conditions, the following relationship holds:
#    * **PV = nRT**
#
# 2. **Temperature Increase:** When temperature increases for an ideal gas, its molecules move faster. This increased
# kinetic energy translates to a higher pressure (more collisions with the container walls).
#
#
# 3. **Volume Increase:**  When volume increases for an ideal gas, the space available for the gas molecules expands.
# To maintain the same number of moles of gas and temperature, the particles must spread out to occupy more space.
# This leads to a decrease in pressure as the molecules are less closely packed (see the effect of volume on pressure
# below).
#
#
#
# **Solving your specific question:**
#
# * **Temperature Increase by Factor of 2:** If the temperature increases by a factor of 2, then you have an equation
# like this:
#    * P1 * V1 = nR * T1
#    *  P2 * V2 = nR * T2
#    * Where T1 is original temperature (initial) and T2 is temperature after increase.
#
#
# **Key Point:** While the ideal gas law simplifies the behavior of gases under certain conditions, real-world gases
# deviate from these assumptions, especially at high pressures and low temperatures, where the "ideal" model breaks
# down more significantly.
#
#
#
# Let me know if you'd like a deeper dive into any specific aspect or want to solve the problem with a particular set
# of values!
# Here's how to determine the change in pressure:
#
# **Understanding the Concepts:**
#
# * **Ideal Gas Law (PV = nRT):** This law governs how the pressure, volume, temperature, and moles of an ideal gas
# are related.
# * **Temperature Increase by a Factor of 2:** The kinetic energy of the gas molecules increases significantly.
# * **Volume Increase by a Factor of 8:** The space available to the gas molecules expands.
#
# **Calculating Pressure Changes**
#
# 1. **Initial Conditions:** Let's say your ideal gas starts at a pressure (P1), volume (V1), and temperature (T1).
#
# 2. **Increased Temperature:** When the temperature increases by a factor of 2, we have new conditions:
#    * T2 = 2 * T1
#     We can use the Ideal Gas Law to relate P1, V1, T1, and the new pressure (P2) at this condition:
#     * P1 * V1 = nR * T1
#     * P2 * V2 = nR * T2
#
# 3. **Increased Volume:** The volume increases by a factor of 8, meaning V2 = 8 * V1
#     We can use the Ideal Gas Law to relate P1, V1, T1, and the new pressure (P2) at this condition:
#     * P1 * V1 = nR * T1
#     * P2 * V2 = nR * T2
#
# **The Relationship:**
#
#
#    * **Pressure Changes:** You can find out how the pressure changes by using these equations.
#
# **Important Notes:**
#
#
#    * **Real-world Gases:** In reality, gases deviate from ideal behavior at high pressures and low temperatures.
# This is because forces between gas molecules become significant in such situations.
#    * **Units:** Make sure to use consistent units for all quantities involved (e.g., Pascals (Pa) for pressure).
#
# Let me know if you have any more questions or would like further clarification on specific steps!

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Paper: https://arxiv.org/pdf/2402.07927
