# %%
import sys
from pathlib import Path

def do_configure_import_path():
    project_root = Path().resolve().parent  # this is ".." relative to the notebook
    if str(project_root) not in sys.path:
        sys.path.insert(0, str(project_root))

do_configure_import_path()

from utils import setup, invoke, printGreen, printRed

setup()
# Out:
# sk-proj-4w
# Installing packages from /Users/jonathan_yarkoni/Advanced Prompt Eng -
# Inficon/Advanced-prompt-engineering-for-developers/requirements.txt ...
# Requirement already satisfied: openai in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from -r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: rich in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from -r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 2)) (14.2.0)
# Requirement already satisfied: dotenv in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from -r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 3)) (0.9.9)
# Requirement already satisfied: langchain in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from -r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 4)) (1.0.7)
# Requirement already satisfied: langchain_community in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from -r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: langchain_core in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from -r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: langchain_openai in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from -r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 7)) (1.0.3)
# Requirement already satisfied: anthropic in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from -r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 8)) (0.74.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (2.12.4)
# Requirement already satisfied: sniffio in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (3.11)
# Requirement already satisfied: certifi in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from rich->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from rich->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: python-dotenv in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from dotenv->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 4)) (1.0.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (0.4.43)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 4)) (1.0.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 4)) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 4)) (1.12.0)
# Requirement already satisfied: orjson>=3.10.1 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 4)) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (0.25.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from langchain_openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 7)) (2025.11.3)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from anthropic->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 8)) (0.17.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->-r /Users/jonathan_yarkoni/Advanced Prompt Eng - Inficon/Advanced-prompt-engineering-for-developers/requirements.txt (line 2)) (0.1.2)
# Package installation complete.

# %% [markdown]
# # LLMs are simply a "Next Token Predictor"

# %%
printGreen(invoke("one, two, "))
# Out:
# three, four

# %%
prompt_1 = 'current'
prompt_2 = 'current sea'
prompt_3 = 'current electric'
prompt_4 = 'current times'

# %%
print(invoke(prompt_1))
print(invoke(prompt_2))
print(invoke(prompt_3))
print(invoke(prompt_4))
# Out:
# The current situation is constantly changing and can vary depending on many different factors. It is important to stay updated and informed on the latest news and developments in order to have an accurate understanding of the current state of affairs.
#  level rise is a significant global challenge and threat to coastal communities around the world. The rising sea levels are primarily caused by the melting of polar ice caps and glaciers due to climate change. This phenomenon is leading to coastal flooding, erosion, and the displacement of communities living in low-lying areas.
#
# Efforts to address and adapt to rising sea levels include implementing coastal protection measures such as seawalls, raising buildings and infrastructure, and restoring natural habitats like wetlands and mangroves. Additionally, reducing carbon emissions and transitioning to renewable energy sources are crucial steps in combatting climate change and mitigating the impacts of sea level rise.
#
# It is essential for governments, communities, and individuals to work together to create sustainable solutions to protect our coastlines and future generations from the devastating effects of rising sea levels.
# The current electric energy market is evolving rapidly, with a growing emphasis on renewable energy sources and the adoption of new technologies such as smart grids and energy storage. Consumers are increasingly demanding cleaner and more sustainable electricity options, leading to the expansion of solar, wind, and other renewable energy projects.
#
# Many countries and regions are implementing policies and regulations to promote the transition to a more sustainable energy system, such as renewable energy targets, carbon pricing mechanisms, and support for energy efficiency programs. In addition, advancements in technology are enabling the development of new business models and services, such as community solar projects, virtual power plants, and peer-to-peer energy trading platforms.
#
# Overall, the current electric energy market is characterized by rapid changes and innovations, driven by the need to address climate change, improve energy security, and reduce costs. This presents both challenges and opportunities for industry stakeholders, including utilities, regulators, consumers, and technology providers.
# The current times refer to the present moment or the period of time that is happening now. It can also refer to the contemporary era or the current state of the world or society. In today's current times, we are living in a fast-paced, technologically advanced world that is constantly changing and evolving.

# %%
# But Mr. Bradley insists he never intended to kill Malcolm, only to confront him about his treachery. However, a
# struggle ensued, leading to the unfortunate conclusion of Malcolm Hargrove's life.
#
# As the truth comes to light, the guests are left in shock. The once-charming tech consultant was now revealed to
# have a dark side, driven to murder by a deep sense of betrayal and revenge. The facade of respectability shattered,
# leaving behind a chilling reminder of the darkness that lurked beneath the surface of the town's elite.
#
# The investigation comes to a close, but the memory of that fateful night lingers on, a cautionary tale of how greed
# and ambition can lead to deadly consequences. The annual charity gala will never be the same, tainted by the
# shadows of a murder that will forever haunt the grand estate of Malcolm Hargrove.

# %%
printGreen(invoke(complicated_murder_plot_missing_solution))
# Out:
# Mr. Bradley

# %% [markdown]
# # Basic structure

# %% [markdown]
# <span style="color:white">
#
# RESPCT framework:
# - (R) Role: Better Semantic Relationships
# - (E) Example: Additional context
# - (S) Structure: Contorl input/output to structure
# - (P) Pipeline: Break the mega prompt
# - (C) Constraints: Limit the model
# - (T) Task: Instructing the model what you want it to do
#
# </span>

# %% [markdown]
# # Role

# %%
role = 'tech lead evaluating junior developer code'

print(invoke(f'You are a {role}, provide constructive feedback and suggestions on this pull request'))
# Out:
# Pull Request: Implementing the login functionality
#
# Feedback:
# 1. It's great to see that you were able to successfully implement the login functionality. Well done!
# 2. The code is generally well-structured and easy to follow.
# 3. I noticed that you have hardcoded some sensitive information, such as the database credentials, in the code. It's important to avoid hardcoding sensitive information like this for security reasons. I would recommend using environment variables or a configuration file to store these values securely.
# 4. Additionally, I noticed that there are no error handling mechanisms in place. It's important to handle potential errors gracefully to provide a better user experience. Consider implementing error handling to catch and handle any exceptions that may arise.
# 5. It would be beneficial to include unit tests to ensure the reliability and quality of the code. Unit tests can help you identify and fix any potential bugs or issues early on in the development process.
# 6. Lastly, consider adding comments to explain the purpose of certain sections of the code or any complex logic. This will make it easier for other developers to understand and maintain the code in the future.
#
# Overall, good job on the implementation. Keep up the good work and continue to strive for improvement in your coding practices. If you have any questions or need further clarification on any of the feedback provided, don't hesitate to reach out.

# %%
role = 'hobo'

print(invoke(f'You are a {role}, provide constructive feedback and suggestions on this pull request'))
# Out:
# Sure, here are some suggestions for this pull request:
#
# 1. Provide more detailed description of the changes that were made in the code. This will help the reviewers understand the purpose of the changes and make it easier for them to provide feedback.
# 2. Consider breaking down the changes into smaller, more manageable chunks. This will make it easier for reviewers to understand and test the changes.
# 3. Make sure to test the changes thoroughly before submitting the pull request. This will help ensure that the code is functional and does not introduce any new bugs.
# 4. Consider adding unit tests or integration tests to cover the changes made in the code. This will help ensure that the code is robust and reliable.
# 5. Address any feedback or comments from reviewers in a timely manner. This will help expedite the review process and ensure that the changes are accepted and merged quickly.

# %% [markdown]
# # Examples
#
# 1. Teach the model patterns
# 2. Add information for solving
#
# ### Zero shot:

# %%
#Here:
#A = Normal operation
#B = System/application error
#C = Performance/health alert
#But the model is not told that — it must infer the logic based on patterns.

prompt = """<task>Your task is to classify log entries into A, B, or C.<task>
        Log: 'Authentication failure for user admin'
        Class: """
#Correct answer is B

print(invoke(prompt))
# Out:
# C

# %% [markdown]
# ### Few Shot:

# %%
#Here:
#A = Normal operation
#B = System/application error
#C = Performance/health alert
#But the model is not told that — it must infer the logic based on patterns.

prompt = """<task>Your task is to classify log entries into A, B, or C.<task>
        Log: 'CPU temperature high'
        Class: C

        Log: 'User logged in successfully'
        Class: A

        Log: 'Database connection failed'
        Class: B

        Log: 'Memory usage at 85%'
        Class: C

        Log: 'New user registered'
        Class: A

        Log: 'Disk I/O error on /dev/sda1'
        Class: B

        Log: 'Password changed successfully'
        Class: A

        Log: 'Timeout while waiting for response from service X'
        Class: B

        Log: 'RAM usage exceeds threshold'
        Class: C

        Log: 'Authentication failure for user admin'
        Class: """

printGreen(invoke(prompt))
# Out:
# B

# %% [markdown]
# # Structure with \<\tags>
#
# 1. For user - Control output format
# 2. For LLM - Simplify internal references

# %%
input = """
            <bug_report>
            When switching from dark mode to light mode, the settings screen sometimes stays dark. 
            This happens on Android 13 only and does not occur on iOS. Users must restart the app 
            to resolve it. Logs show an unhandled UI thread exception.
            </bug_report>

            Extract the <platform>, <trigger>, <impact>, and <workaround> from the <bug_report>.

            In the answer use the following format:
            Platform: <platform>
            ____
            Trigger: <trigger>
            Impact: <impact>
            Workaround: <workaround>
            """


print(invoke(input))
# Out:
# Platform: Android 13
# ____
# Trigger: Switching from dark mode to light mode
# Impact: Settings screen staying dark, requiring app restart to resolve
# Workaround: Restarting the app

# %%
input = """
            <bug_report>
            When switching from dark mode to light mode, the settings screen sometimes stays dark. 
            This happens on Android 13 only and does not occur on iOS. Users must restart the app 
            to resolve it. Logs show an unhandled UI thread exception.
            </bug_report>

            Extract the <platform>, <trigger>, <impact>, and <workaround> from the <bug_report>.

            In the answer use the following format:
            Platform: <platform>
            ____
            Workaround: <workaround>
            """


print(invoke(input))
# Out:
# Platform: Android 13
# ____
# Workaround: Users must restart the app to resolve the issue.

# %% [markdown]
# # Pipeline

# %%
prompt = """
Define the data model for a user in Python using pydantic. Fields: id, name, email, password (hashed).
Given the user model defined with pydantic, write validation rules to ensure email is valid and password is at least 8 characters.
Using Flask, write a POST /users endpoint that receives a JSON payload, validates it with the pydantic model, and returns 201 on success or 400 on validation error.
Improve the /users endpoint by handling duplicate email errors and returning appropriate messages.
"""
print(invoke(prompt))
# Out:
# First, let's define the user data model using pydantic:
#
# ```python
# from pydantic import BaseModel, constr, EmailStr, validator
#
# class User(BaseModel):
#     id: int
#     name: str
#     email: EmailStr
#     password: constr(min_length=8)
#
#     @validator('password')
#     def validate_password(cls, v):
#         if len(v) < 8:
#             raise ValueError('Password must be at least 8 characters long')
#         return v
# ```
#
# Next, let's create a Flask endpoint that handles POST requests to create a new user:
#
# ```python
# from flask import Flask, request, jsonify
# from pydantic import ValidationError
#
# app = Flask(__name__)
#
# @app.route('/users', methods=['POST'])
# def create_user():
#     try:
#         user_data = request.json
#         user = User(**user_data)
#         # Check for duplicate email
#         # Code to check if email already exists in database
#         # Example: if User.query.filter_by(email=user.email).first():
#         return jsonify({'message': 'User created successfully'}), 201
#     except ValidationError as e:
#         return jsonify({'error': e.errors()}), 400
# ```
#
# To handle duplicate email errors, you can add a check in the `create_user` function to see if the email already exists in your database. In the example above, we have added a comment on where you can add this check. If the email already exists, you can return an appropriate error message like:
#
# ```python
# return jsonify({'error': 'Email already exists'}), 400
# ```
#
# Make sure to modify the check for duplicate emails based on how your data is stored in your database.

# %%
#Step 1: Define the Data Model
prompt_1 = "Define the data model for a user in Python using pydantic. Fields: id, name, email, password (hashed)."
print(invoke(prompt_1))

#Step 2: Write the Validation Logic
prompt_2 = "Given the user model defined with pydantic, write validation rules to ensure email is valid and password is at least 8 characters."
print(invoke(prompt_2))

#Step 3: Write the Flask Endpoint
prompt_3 = "Using Flask, write a POST /users endpoint that receives a JSON payload, validates it with the pydantic model, and returns 201 on success or 400 on validation error."
print(invoke(prompt_3))

#Step 4: Add Error Handling and Edge Cases
prompt_4 = "Improve the /users endpoint by handling duplicate email errors and returning appropriate messages."
print(invoke(prompt_4))
# Out:
# from pydantic import BaseModel
#
# class User(BaseModel):
#     id: int
#     name: str
#     email: str
#     password: str
# Here is an example of how you can define a user model with validation rules using Pydantic:
#
# ```python
# from pydantic import BaseModel, EmailStr
#
# class User(BaseModel):
#     email: EmailStr
#     password: str
#
#     @validator('password')
#     def password_length(cls, v):
#         if len(v) < 8:
#             raise ValueError('Password must be at least 8 characters long')
#         return v
# ```
#
# In this example, we have defined a `User` model with `email` and `password` fields. We have used `EmailStr` type for the `email` field to ensure it is a valid email address. We have also added a validator for the `password` field to check that it is at least 8 characters long. If the validation fails, a `ValueError` will be raised with an appropriate error message.
#
# You can then create instances of the `User` model and Pydantic will automatically validate the input data according to the rules defined in the model.
# from flask import Flask, request, jsonify
# from pydantic import BaseModel, ValidationError
# import json
#
# app = Flask(__name__)
#
# class User(BaseModel):
#     name: str
#     email: str
#
# @app.route('/users', methods=['POST'])
# def create_user():
#     data = request.get_json()
#     try:
#         user = User(**data)
#     except ValidationError as e:
#         error_messages = []
#         for error in e.errors():
#             error_messages.append(error['msg'])
#         return jsonify({'error': error_messages}), 400
#
#     # User creation success
#     # Save user data to database or perform any other operations
#     return jsonify({'message': 'User created successfully'}), 201
#
# if __name__ == '__main__':
#     app.run(debug=True)
# To improve the /users endpoint and handle duplicate email errors, you can add a check to see if the email address already exists in the database before attempting to create a new user with that email. If a duplicate email error is encountered, you can return an appropriate error message to the client.
#
# Here's an example of how you can implement this:
#
# 1. Check if the email address already exists before creating a new user:
#
# ```python
# @app.route('/users', methods=['POST'])
# def create_user():
#     data = request.json
#     email = data.get('email')
#
#     existing_user = User.query.filter_by(email=email).first()
#
#     if existing_user:
#         return jsonify({'message': 'Email address already exists'}), 400
#
#     # Create new user
#     # Your code to create a new user goes here
# ```
#
# 2. Return appropriate error messages to the client:
#
# In the example above, if a duplicate email error is encountered, a JSON response with an appropriate error message ('Email address already exists') and a status code of 400 (Bad Request) will be returned to the client.
#
# By implementing this check, you can ensure that duplicate email errors are handled gracefully and provide informative messages to users when they try to create an account with an email address that already exists in the database.

# %% [markdown]
# ## Chaining example

# %%
from langchain_core.runnables import RunnableLambda, RunnableSequence
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo")

# Step 1: Generate the model code
step_1 = PromptTemplate.from_template(
    "Define a pydantic model for a user with id, name, email, and password."
) | llm

# Step 2: Add validation to the model code
step_2 = (
    RunnableLambda(lambda model_code: {"model_code": model_code})
    | PromptTemplate.from_template("Add validation to this model:\n{model_code}")
    | llm
    | RunnableLambda(lambda validation_code, model_code=None: {"model_code": model_code, "validation_code": validation_code})
)

# Step 3: Write Flask endpoint using model and validation code
step_3 = (
    PromptTemplate.from_template("Write Flask endpoint using:\nModel:\n{model_code}\nValidation:\n{validation_code}")
    | llm
)

# Step 4: Improve with duplicate email error handling
step_4 = (
    RunnableLambda(lambda endpoint_code: {"endpoint_code": endpoint_code})
    | PromptTemplate.from_template("Improve with duplicate email error handling:\n{endpoint_code}")
    | llm
)

# Combine steps in a sequence
pipeline = RunnableSequence(
    step_1,
    step_2,
    step_3,
    step_4,
)

final_output = pipeline.invoke({})
print(final_output.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 2
#       1 from langchain_core.runnables import RunnableLambda, RunnableSequence
# ----> 2 from langchain.prompts import PromptTemplate
#       3 from langchain_openai import ChatOpenAI
#       5 llm = ChatOpenAI(model="gpt-3.5-turbo")
#
# ModuleNotFoundError: No module named 'langchain.prompts'

# %% [markdown]
# # Task

# %%
prompt = """<task>Write an on-call schedule for 3 engineers across 2 services</task>"""
print(invoke(prompt))
# Out:
# On-Call Schedule:
#
# Engineer 1:
# - Monday: Service 1
# - Tuesday: Service 2
# - Wednesday: Service 1
# - Thursday: Service 2
# - Friday: Service 1
# - Saturday: Service 2
# - Sunday: Off
#
# Engineer 2:
# - Monday: Service 2
# - Tuesday: Service 1
# - Wednesday: Service 2
# - Thursday: Service 1
# - Friday: Service 2
# - Saturday: Service 1
# - Sunday: Off
#
# Engineer 3:
# - Monday: Service 1
# - Tuesday: Service 2
# - Wednesday: Service 1
# - Thursday: Service 2
# - Friday: Service 1
# - Saturday: Service 2
# - Sunday: Off
#
# This schedule ensures that each engineer rotates between the two services and has a day off each week.

# %% [markdown]
# # Constraints

# %%
prompt = """<task>Write an on-call schedule for 3 engineers across 2 services</task>
                <constraints>
                1. Each engineer must only support 1 service per shift
                2. No engineer can be on-call more than 8 hours per day
                3. There must always be 1 engineer per service at any time
                4. Engineers must have at least 12 hours of rest between shifts
                </constraints>"""
print(invoke(prompt))
# Out:
# On-Call Schedule:
#
# Engineer 1:
# - Day 1: Service 1 (8am - 4pm)
# - Day 2: Rest (4pm - 8am)
# - Day 3: Rest (8am - 8pm)
#
# Engineer 2:
# - Day 1: Service 2 (4pm - 12am)
# - Day 2: Rest (12am - 8am)
# - Day 3: Rest (8am - 8pm)
#
# Engineer 3:
# - Day 1: Service 1 (12am - 8am)
# - Day 2: Rest (8am - 4pm)
# - Day 3: Service 2 (8pm - 4am)
